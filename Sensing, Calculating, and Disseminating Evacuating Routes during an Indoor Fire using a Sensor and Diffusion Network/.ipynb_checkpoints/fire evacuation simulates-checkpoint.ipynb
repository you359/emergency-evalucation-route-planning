# %%
from fire_evacuation import simulate
from config import available_coord

import numpy as np
import matplotlib.pyplot as plt
import random
from tqdm import tqdm

# %matplotlib notebook

# %%
success = 0
for i in tqdm(range(10)):

    fire_x_coordinate = random.randrange(50)
    fire_y_coordinate = random.randrange(50)
    fire_coordinate = (fire_x_coordinate, fire_y_coordinate)

    occupant_coordinate = available_coord[random.randrange(len(available_coord))]

    print(fire_coordinate, occupant_coordinate)

    result = simulate(fire_speed=1,
                      occupant_speed=1,
                      fire_coordinate=fire_coordinate,
                      occupant_coordinate=occupant_coordinate,
                      visualize=True)
    success += result

    print("Success ratio: {}".format(success / (i + 1)))
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# (11, 0) (36, 21)
# <img src="data:image/png;base64,..." width="640">
# success!
# Success ratio: 1.0
#  10%|████████▎                                                                          | 1/10 [00:11<01:42, 11.42s/it]
# (24, 35) (44, 11)
# <img src="data:image/png;base64,..." width="640">
# failed!
# Success ratio: 0.5
#  20%|████████████████▌                                                                  | 2/10 [00:25<01:38, 12.36s/it]
# (48, 13) (36, 24)
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-f4d9e995229a> in <module>()
#      14                       fire_coordinate=fire_coordinate,
#      15                       occupant_coordinate=occupant_coordinate,
# ---> 16                       visualize=True)
#      17     success += result
#      18
#
# G:\github\emergency-evalucation-route-planning\Sensing, Calculating, and Disseminating Evacuating Routes during an Indoor Fire using a Sensor and Diffusion Network\fire_evacuation.py in simulate(fire_speed, occupant_speed, fire_coordinate, occupant_coordinate, visualize)
#     117             # plt.draw()
#     118             fig.canvas.draw()
# --> 119             plt.pause(0.3)
#     120             colorbar.remove()
#     121
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pause(interval)
#     293             canvas.draw_idle()
#     294         show(block=False)
# --> 295         canvas.start_event_loop(interval)
#     296     else:
#     297         time.sleep(interval)
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in start_event_loop(self, timeout)
#    2250         while self._looping and counter * timestep < timeout:
#    2251             self.flush_events()
# -> 2252             time.sleep(timestep)
#    2253             counter += 1
#    2254
#
# KeyboardInterrupt:
